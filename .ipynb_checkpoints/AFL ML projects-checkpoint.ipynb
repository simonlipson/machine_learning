# %%
import pandas as pd
from sklearn import metrics
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, ElasticNet
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn.neighbors import KNeighborsClassifier, KNeighborsRegressor
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from matplotlib import pyplot

# %%
features = pd.read_csv('/Users/simonlipson/Downloads/aflstats/stats.csv')

# %%
features.head()
# Out:
#        Team        Player       D.O.B  Height  Weight  Position  Season Round  \
# 0  Adelaide  Atkins, Rory  1994-07-12     186      85  Midfield    2018    R1
# 1  Adelaide  Betts, Eddie  1986-11-26     174      74   Forward    2018    R1
# 2  Adelaide   Brown, Luke  1992-09-22     181      81  Defender    2018    R1
# 3  Adelaide  Crouch, Matt  1995-04-21     182      80  Midfield    2018    R1
# 4  Adelaide   Doedee, Tom  1997-03-01     188      88  Defender    2018    R1
#
#          Date  Score  ...  FreesAgainst BrownlowVotes ContendedPossessions  \
# 0  2018-03-23   87.0  ...             0             0                    4
# 1  2018-03-23   87.0  ...             0             0                    6
# 2  2018-03-23   87.0  ...             0             0                    1
# 3  2018-03-23   87.0  ...             1             0                   11
# 4  2018-03-23   87.0  ...             0             0                    8
#
#   UncontendedPossessions  ContestedMarks  MarksInside50  OnePercenters  \
# 0                      9               0              0              0
# 1                      9               0              1              3
# 2                     10               0              0              2
# 3                     31               0              0              0
# 4                     14               0              0              9
#
#    Bounces  GoalAssists  PercentPlayed
# 0        0            1             86
# 1        0            1             85
# 2        0            0             82
# 3        0            1             80
# 4        1            0             93
#
# [5 rows x 37 columns]

# %%
features.shape
# Out:
# (63712, 37)

# %%
features.columns
# Out:
# Index(['Team', 'Player', 'D.O.B', 'Height', 'Weight', 'Position', 'Season',
#        'Round', 'Date', 'Score', 'Margin', 'WinLoss', 'Opposition', 'Venue',
#        'Disposals', 'Kicks', 'Marks', 'Handballs', 'Goals', 'Behinds',
#        'Hitouts', 'Tackles', 'Rebound50s', 'Inside50s', 'Clearances',
#        'Clangers', 'FreesFor', 'FreesAgainst', 'BrownlowVotes',
#        'ContendedPossessions', 'UncontendedPossessions', 'ContestedMarks',
#        'MarksInside50', 'OnePercenters', 'Bounces', 'GoalAssists',
#        'PercentPlayed'],
#       dtype='object')

# %%
features['new_index'] = features['Season'].astype(str) + features['Team'] + features['Round']

# %%
features.groupby('new_index').count()
# Out:
#                         Team  Player  D.O.B  Height  Weight  Position  Season  \
# new_index
# 2012AdelaidePF            22      22     22      22      22        22      22
# 2012AdelaideQF            22      22     22      22      22        22      22
# 2012AdelaideR1            22      22     22      22      22        22      22
# 2012AdelaideR10           22      22     22      22      22        22      22
# 2012AdelaideR12           22      22     22      22      22        22      22
# ...                      ...     ...    ...     ...     ...       ...     ...
# 2018Western BulldogsR5    22      22     22      22      22        22      22
# 2018Western BulldogsR6    22      22     22      22      22        22      22
# 2018Western BulldogsR7    22      22     22      22      22        22      22
# 2018Western BulldogsR8    22      22     22      22      22        22      22
# 2018Western BulldogsR9    22      22     22      22      22        22      22
#
#                         Round  Date  Score  ...  FreesAgainst  BrownlowVotes  \
# new_index                                   ...
# 2012AdelaidePF             22    22     22  ...            22             22
# 2012AdelaideQF             22    22     22  ...            22             22
# 2012AdelaideR1             22    22     22  ...            22             22
# 2012AdelaideR10            22    22     22  ...            22             22
# 2012AdelaideR12            22    22     22  ...            22             22
# ...                       ...   ...    ...  ...           ...            ...
# 2018Western BulldogsR5     22    22     22  ...            22             22
# 2018Western BulldogsR6     22    22     22  ...            22             22
# 2018Western BulldogsR7     22    22     22  ...            22             22
# 2018Western BulldogsR8     22    22     22  ...            22             22
# 2018Western BulldogsR9     22    22     22  ...            22             22
#
#                         ContendedPossessions  UncontendedPossessions  \
# new_index
# 2012AdelaidePF                            22                      22
# 2012AdelaideQF                            22                      22
# 2012AdelaideR1                            22                      22
# 2012AdelaideR10                           22                      22
# 2012AdelaideR12                           22                      22
# ...                                      ...                     ...
# 2018Western BulldogsR5                    22                      22
# 2018Western BulldogsR6                    22                      22
# 2018Western BulldogsR7                    22                      22
# 2018Western BulldogsR8                    22                      22
# 2018Western BulldogsR9                    22                      22
#
#                         ContestedMarks  MarksInside50  OnePercenters  Bounces  \
# new_index
# 2012AdelaidePF                      22             22             22       22
# 2012AdelaideQF                      22             22             22       22
# 2012AdelaideR1                      22             22             22       22
# 2012AdelaideR10                     22             22             22       22
# 2012AdelaideR12                     22             22             22       22
# ...                                ...            ...            ...      ...
# 2018Western BulldogsR5              22             22             22       22
# 2018Western BulldogsR6              22             22             22       22
# 2018Western BulldogsR7              22             22             22       22
# 2018Western BulldogsR8              22             22             22       22
# 2018Western BulldogsR9              22             22             22       22
#
#                         GoalAssists  PercentPlayed
# new_index
# 2012AdelaidePF                   22             22
# 2012AdelaideQF                   22             22
# 2012AdelaideR1                   22             22
# 2012AdelaideR10                  22             22
# 2012AdelaideR12                  22             22
# ...                             ...            ...
# 2018Western BulldogsR5           22             22
# 2018Western BulldogsR6           22             22
# 2018Western BulldogsR7           22             22
# 2018Western BulldogsR8           22             22
# 2018Western BulldogsR9           22             22
#
# [2896 rows x 37 columns]

# %%
features = features.groupby('new_index').agg(
win_loss = pd.NamedAgg(column = 'WinLoss', aggfunc = 'max'),
margin = pd.NamedAgg(column = 'Margin', aggfunc = 'max'),
disposals = pd.NamedAgg(column = 'Disposals', aggfunc = 'sum'),
kicks = pd.NamedAgg(column = 'Kicks', aggfunc = 'sum'),
marks = pd.NamedAgg(column = 'Marks', aggfunc = 'sum'),
handballs = pd.NamedAgg(column = 'Handballs', aggfunc = 'sum'),
hitouts = pd.NamedAgg(column = 'Hitouts', aggfunc = 'sum'),
tackles = pd.NamedAgg(column = 'Tackles', aggfunc = 'sum'),
rebound50s = pd.NamedAgg(column = 'Rebound50s', aggfunc = 'sum'),
inside50s = pd.NamedAgg(column = 'Inside50s', aggfunc = 'sum'),
clearances = pd.NamedAgg(column = 'Clearances', aggfunc = 'sum'),
clangers = pd.NamedAgg(column = 'Clangers', aggfunc = 'sum'),
freesfor = pd.NamedAgg(column = 'FreesFor', aggfunc = 'sum'),
freesagainst = pd.NamedAgg(column = 'FreesAgainst', aggfunc = 'sum'),
contendedpossessions = pd.NamedAgg(column = 'ContendedPossessions', aggfunc = 'sum'),
uncontendedpossessions = pd.NamedAgg(column = 'UncontendedPossessions', aggfunc = 'sum'),
contestedmarks = pd.NamedAgg(column = 'ContestedMarks', aggfunc = 'sum'),
marksinside50 = pd.NamedAgg(column = 'MarksInside50', aggfunc = 'sum'),
oncepercenters = pd.NamedAgg(column = 'OnePercenters', aggfunc = 'sum'),
bounces = pd.NamedAgg(column = 'Bounces', aggfunc = 'sum')
)

# %%
features.isnull().sum()
# Out:
# win_loss                  4
# margin                    4
# disposals                 0
# kicks                     0
# marks                     0
# handballs                 0
# hitouts                   0
# tackles                   0
# rebound50s                0
# inside50s                 0
# clearances                0
# clangers                  0
# freesfor                  0
# freesagainst              0
# contendedpossessions      0
# uncontendedpossessions    0
# contestedmarks            0
# marksinside50             0
# oncepercenters            0
# bounces                   0
# dtype: int64

# %%
features.dropna(inplace=True)

# %%
features.shape
# Out:
# (2892, 20)

# %%
features.head()
# Out:
#                 win_loss  margin  disposals  kicks  marks  handballs  hitouts  \
# new_index
# 2012AdelaidePF         L    -5.0        363    213    115        150       45
# 2012AdelaideQF         L   -29.0        334    201     79        133       42
# 2012AdelaideR1         W    69.0        406    252    109        154       42
# 2012AdelaideR10        W    29.0        351    215     85        136       34
# 2012AdelaideR12        W     4.0        373    224     87        149       63
#
#                  tackles  rebound50s  inside50s  clearances  clangers  \
# new_index
# 2012AdelaidePF        39          47         38          33        52
# 2012AdelaideQF        50          26         59          33        50
# 2012AdelaideR1        73          28         73          39        47
# 2012AdelaideR10       58          29         48          52        41
# 2012AdelaideR12       59          35         56          36        46
#
#                  freesfor  freesagainst  contendedpossessions  \
# new_index
# 2012AdelaidePF         22            24                   126
# 2012AdelaideQF         23            17                   146
# 2012AdelaideR1         15            16                   152
# 2012AdelaideR10        20            14                   155
# 2012AdelaideR12        16            16                   166
#
#                  uncontendedpossessions  contestedmarks  marksinside50  \
# new_index
# 2012AdelaidePF                      241              15             12
# 2012AdelaideQF                      185              11              6
# 2012AdelaideR1                      249              10             16
# 2012AdelaideR10                     201              11             12
# 2012AdelaideR12                     207              13             15
#
#                  oncepercenters  bounces
# new_index
# 2012AdelaidePF               47       18
# 2012AdelaideQF               55       17
# 2012AdelaideR1               42        1
# 2012AdelaideR10              57        4
# 2012AdelaideR12              39        9

# %%
X_test = features.filter(regex='2018', axis=0).iloc[:,2:20]

# %%
X_train = features.filter(regex='2012|2013|2014|2015|2016|2017', axis=0).iloc[:,2:20]

# %%
y_test = features.filter(regex='2018', axis=0).iloc[:,0]

# %%
y_train = features.filter(regex='2012|2013|2014|2015|2016|2017', axis=0).iloc[:,0]

# %%
models = []
models.append(('LR', LogisticRegression(solver='liblinear', multi_class='ovr')))
models.append(('LDA', LinearDiscriminantAnalysis()))
models.append(('KNN', KNeighborsClassifier()))
models.append(('CART', DecisionTreeClassifier()))
models.append(('NB', GaussianNB()))
models.append(('SVM', SVC(gamma='auto')))
# evaluate each model in turn
results = []
names = []
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    cv_results = cross_val_score(model, X_train, y_train, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    print('%s: %f (%f)' % (name, cv_results.mean(), cv_results.std()))
# Out:
# LR: 0.791310 (0.028388)
# LDA: 0.811049 (0.024933)
# KNN: 0.729256 (0.023844)
# CART: 0.698201 (0.035045)
# NB: 0.765512 (0.018004)
# SVM: 0.496779 (0.002875)

# %%
# Compare Algorithms
pyplot.boxplot(results, labels=names)
pyplot.title('Algorithm Comparison')
pyplot.show()

# %%
model = LinearDiscriminantAnalysis()
model.fit(X_test, y_test)
# Out:
# LinearDiscriminantAnalysis(n_components=None, priors=None, shrinkage=None,
#                            solver='svd', store_covariance=False, tol=0.0001)

# %%
y_pred = model.predict(X_test)

# %%
result = pd.DataFrame({'actual': y_test,
                      'prediction': y_pred})

# %%
result
# Out:
#                        actual prediction
# new_index
# 2018AdelaideR1              L          L
# 2018AdelaideR10             L          L
# 2018AdelaideR11             L          W
# 2018AdelaideR12             L          L
# 2018AdelaideR13             L          L
# ...                       ...        ...
# 2018Western BulldogsR5      L          L
# 2018Western BulldogsR6      W          W
# 2018Western BulldogsR7      W          W
# 2018Western BulldogsR8      W          W
# 2018Western BulldogsR9      L          L
#
# [410 rows x 2 columns]

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            D       1.00      1.00      1.00         2
#            L       0.85      0.86      0.86       204
#            W       0.86      0.85      0.85       204
#
#     accuracy                           0.86       410
#    macro avg       0.90      0.90      0.90       410
# weighted avg       0.86      0.86      0.86       410

# %%
print(model.coef_[0])
# Out:
# [-0.21627126 -0.11627914 -0.17604095 -0.24028508  0.01990706  0.03368162
#   0.39174524  0.23147814 -0.19789116 -0.31579277 -0.07105508  0.1701444
#   0.38229008  0.44860921 -0.41091044  0.09382046  0.03189118  0.07460038]

# %%
importance = model.coef_[0]

for i,v in enumerate(importance):
	print('{}, Score: {}}'.format(X_traini,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: -0.21627
# Feature: 1, Score: -0.11628
# Feature: 2, Score: -0.17604
# Feature: 3, Score: -0.24029
# Feature: 4, Score: 0.01991
# Feature: 5, Score: 0.03368
# Feature: 6, Score: 0.39175
# Feature: 7, Score: 0.23148
# Feature: 8, Score: -0.19789
# Feature: 9, Score: -0.31579
# Feature: 10, Score: -0.07106
# Feature: 11, Score: 0.17014
# Feature: 12, Score: 0.38229
# Feature: 13, Score: 0.44861
# Feature: 14, Score: -0.41091
# Feature: 15, Score: 0.09382
# Feature: 16, Score: 0.03189
# Feature: 17, Score: 0.07460

# %%
y_test1 = features.filter(regex='2018', axis=0).iloc[:,1]

# %%
y_train1 = features.filter(regex='2012|2013|2014|2015|2016|2017', axis=0).iloc[:,1]

# %%
models = []
models.append(('LR',LinearRegression()))
models.append(('LASSO', Lasso()))
models.append(('EN', ElasticNet()))
models.append(('KNN', KNeighborsRegressor()))
models.append(('CART', DecisionTreeRegressor()))
models.append(('GBM', GradientBoostingRegressor()))

results = []
names = []
for name, model in models:
    kfold = StratifiedKFold(n_splits=10, random_state=1, shuffle=True)
    cv_results = cross_val_score(model, X_train, y_train1, cv=kfold, scoring='r2')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# LR: 0.669927 (0.020176)
# LASSO: 0.669910 (0.020544)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1957.8781849101651, tolerance: 483.52964245409765
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11751.007929322543, tolerance: 483.02809896999565
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1482.920661780052, tolerance: 485.4459735004477
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1633.6479005187284, tolerance: 480.7807353625782
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2338.2804950280115, tolerance: 484.3536513876454
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2050.3781968858093, tolerance: 481.0635697851387
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2606.9716820116155, tolerance: 485.3014063115491
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14471.99828763213, tolerance: 481.56435541629367
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1864.9297422775999, tolerance: 481.51302112802165
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:474: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1521.3276332111564, tolerance: 479.4002709489706
#   model = cd_fast.enet_coordinate_descent(
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# EN: 0.669843 (0.020241)
# KNN: 0.493817 (0.034722)
# CART: 0.235990 (0.062855)
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/sklearn/model_selection/_split.py:665: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(("The least populated class in y has only %d"
# GBM: 0.657626 (0.027957)

# %%
pyplot.boxplot(results, labels=names)
pyplot.title('Algorithm Comparison')
pyplot.show()

# %%
model = LinearRegression()
model.fit(X_test, y_test1)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
y_pred = model.predict(X_test)

# %%
result2 = pd.DataFrame({'actual1': y_test1,
                      'prediction1': y_pred})

# %%
result2
# Out:
#                         actual1  prediction1
# new_index
# 2018AdelaideR1            -12.0   -11.946186
# 2018AdelaideR10           -91.0   -53.316523
# 2018AdelaideR11           -16.0    14.761262
# 2018AdelaideR12            -3.0   -14.882648
# 2018AdelaideR13           -56.0   -54.202132
# ...                         ...          ...
# 2018Western BulldogsR5    -54.0   -52.662983
# 2018Western BulldogsR6     21.0     8.763220
# 2018Western BulldogsR7      9.0    38.249044
# 2018Western BulldogsR8     14.0    47.198820
# 2018Western BulldogsR9    -37.0     1.503941
#
# [410 rows x 2 columns]

# %%
merged_results = pd.merge(result, result2, left_index=True, right_index=True)

# %%
merged_results
# Out:
#                        actual prediction  actual1  prediction1
# new_index
# 2018AdelaideR1              L          L    -12.0   -11.946186
# 2018AdelaideR10             L          L    -91.0   -53.316523
# 2018AdelaideR11             L          W    -16.0    14.761262
# 2018AdelaideR12             L          L     -3.0   -14.882648
# 2018AdelaideR13             L          L    -56.0   -54.202132
# ...                       ...        ...      ...          ...
# 2018Western BulldogsR5      L          L    -54.0   -52.662983
# 2018Western BulldogsR6      W          W     21.0     8.763220
# 2018Western BulldogsR7      W          W      9.0    38.249044
# 2018Western BulldogsR8      W          W     14.0    47.198820
# 2018Western BulldogsR9      L          L    -37.0     1.503941
#
# [410 rows x 4 columns]

# %%
merged_results['delta'] = abs(merged_results['actual1']) - abs(merged_results['prediction1'])

# %%
merged_results
# Out:
#                        actual prediction  actual1  prediction1      delta
# new_index
# 2018AdelaideR1              L          L    -12.0   -11.946186   0.053814
# 2018AdelaideR10             L          L    -91.0   -53.316523  37.683477
# 2018AdelaideR11             L          W    -16.0    14.761262   1.238738
# 2018AdelaideR12             L          L     -3.0   -14.882648 -11.882648
# 2018AdelaideR13             L          L    -56.0   -54.202132   1.797868
# ...                       ...        ...      ...          ...        ...
# 2018Western BulldogsR5      L          L    -54.0   -52.662983   1.337017
# 2018Western BulldogsR6      W          W     21.0     8.763220  12.236780
# 2018Western BulldogsR7      W          W      9.0    38.249044 -29.249044
# 2018Western BulldogsR8      W          W     14.0    47.198820 -33.198820
# 2018Western BulldogsR9      L          L    -37.0     1.503941  35.496059
#
# [410 rows x 5 columns]

# %%
merged_results['delta'].mean()
# Out:
# 5.707401996947569

# %%
print(metrics.mean_squared_error(y_test1, y_pred))
print(metrics.r2_score(y_test1, y_pred))
# Out:
# 582.6778059098233
# 0.6683502878908232

# %%
num_bins = 20
n, bins, patches = pyplot.hist(merged_results['delta'], num_bins, facecolor='blue', alpha=0.5)
pyplot.show()
